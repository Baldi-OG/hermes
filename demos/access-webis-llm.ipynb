# %% [markdown]
# # Webis OpenAI API
#
# @students: Without VPN you probably won't be able to access these websites, but the cells below contain the same content
# - Refer to [Knowledge Base](https://kb.webis.de/services/llm-staging/index.html#openai-api-authenticated-recommended)
# - [Available models](https://llm.srv.webis.de/openai/v1/models)

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.config import CONFIG
from openai import OpenAI

client = OpenAI(
   base_url=CONFIG.WEBIS_URL_WEBUI,
   api_key=CONFIG.WEBIS_KEY_WEBUI,
)

# %%
models = client.models.list()

for m in models.data:
    print(m.id)
# Out:
# qwen3-30b-a3b-cpu
# gemma2-2b
# mistral-7b
# deepseek-r1-14b
# gpt-oss-20b-cpu
# llama3-8b
# nomic-embed-text
# qwen3-0.6b-cpu
# qwen3-1.7b
# deepseek-r1-8b
# gemma3-4b
# llama3.1-8b
# smollm2-1.7b-cpu
# zephyr-7b
# llava-13b
# qwen3-8b
# deepseek-r1-1.5b-cpu
# qwen3-1.7b-cpu
# deepseek-r1-7b
# gemma3-1b-cpu
# llama3.2-3b
# phi3-3.8b
# vicuna-7b
# gemma3-270m-cpu
# gpt-oss-20b
# qwen3-30b-a3b
# tinyllama-1.1b-cpu

# %%
client.chat.completions.create(
   model='llama3.2-3b',
   messages=[
      {
         'role': 'user',
         'content': 'Why is the sky blue?',
      },
   ],
)
# Out:
# ChatCompletion(id='chatcmpl-923', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The sky appears blue because of a phenomenon called Rayleigh scattering, named after the British physicist Lord Rayleigh. He first described it in the late 19th century.\n\nHere's what happens:\n\n1. **Sunlight and atmosphere**: When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2).\n2. **Scattering**: These molecules scatter the light in all directions, but they scatter shorter (blue) wavelengths more than longer (red) wavelengths.\n3. **Blue light prevalence**: Since blue light is scattered more than red light, our eyes are exposed to more blue light when looking at the sky.\n4. **Perception**: As we look up at the sky, our brains interpret the scattered blue light as the dominant color, which appears blue to us.\n\nSo, in simple terms, the reason the sky looks blue is that:\n\n * Blue l
# ...
