# %% [markdown]
# # Webis OpenAI API
#
# @students: Without VPN you probably won't be able to access these websites, but the cells below contain the same content
# - Refer to [Knowledge Base](https://kb.webis.de/services/llm-staging/index.html#openai-api-authenticated-recommended)
# - [Available models](https://llm.srv.webis.de/openai/v1/models)

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from config import CONFIG
from openai import OpenAI

client = OpenAI(
   base_url=CONFIG.WEBIS_URL_WEBUI,
   api_key=CONFIG.WEBIS_KEY_WEBUI,
)

# %%
models = client.models.list()

for m in models.data:
    print(m.id)
# Out:
# gemma3-270m-cpu
# gpt-oss-20b-cpu
# llama3-8b
# llama3.1-8b
# tinyllama-1.1b-cpu
# llama3.2-3b
# qwen3-1.7b
# qwen3-30b-a3b
# qwen3-30b-a3b-cpu
# qwen3-8b
# vicuna-7b
# deepseek-r1-1.5b-cpu
# deepseek-r1-14b
# gemma2-2b
# gemma3-4b
# llava-13b
# phi3-3.8b
# deepseek-r1-7b
# gpt-oss-20b
# gemma3-1b-cpu
# nomic-embed-text
# mistral-7b
# zephyr-7b
# llama3-sqlcoder-8b
# qwen3-1.7b-cpu
# smollm2-1.7b-cpu
# deepseek-r1-8b
# qwen3-0.6b-cpu

# %%
client.chat.completions.create(
   model='deepseek-r1-8b',
   messages=[
      {
         'role': 'user',
         'content': 'Why is the sky blue?',
      },
   ],
)
# Out:
# ChatCompletion(id='chatcmpl-893', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='That\'s one of the most classic science questions! The sky appears blue during the day for the same reason ice is slippery – it\'s because of how sunlight interacts with our atmosphere.\n\nHere\'s the simple explanation:\n\n1.  **Sunlight is White (Mostly):** Sunlight appearing from space is white because it\'s made up of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, violet).\n2.  **The Atmosphere Scatters Light:** When sunlight travels through Earth\'s atmosphere, it interacts with tiny gas molecules (like nitrogen and oxygen) and small particles. This interaction scatters the light in all directions, meaning some light travels straight forward while some bends away from its original path.\n3.  **Not All Colors Scattered Equally:** When Sir Isaac Newton first showed that sunlight is made of color in the 1600s, we learned that light can be scattered differently depending on its wavelength (a fancy term for the color’s "size" on the light spectrum).\n    *   **Shorter Wavelength Colors = More Scattering:** Colors with shorter wavelengths (like violet and blue) interact more strongly with the small atmospheric molecules.\n    *   **Longer Wavelength Colors = Less Scattering:** Colors with longer wavelengths (like red and yellow) barely notice the atmospheric molecules and keep traveling more or less straight ahead.\n4.  **The Blue Result:** The sunlight entering Earth\'s atmosphere contains all the rainbow colors. But the violet and blue light gets scattered strongly *all around* us, like dust particles floating in a beam of light (sometimes called a "dust beam"). When you look up at the sky, you are seeing the light that has been scattered by the atmosphere.\n    *   It\'s the scattered violet and blue light hitting your eyes that makes the *entire* sky appear blue, not any specific scattered beam of one color.\n\n**To summarize:** Sunlight contains all colors. As sunlight passes through the atmosphere, the shortest wavelengths (blue and violet) scatter most strongly in all directions. The sky\'s color is simply what you see from that scattered light – primarily blue.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning="Okay, the user asked why the sky is blue. This is a classic question, often taught in schools. I should start by recalling the correct scientific explanation—in Rayleigh scattering. But first, I need to see if the user is familiar with basic concepts like sunlight and colors. They might be a student or someone curious about science.\n\nThe user's primary need is to understand the science behind the blue sky. But maybe they're also interested in learning how other colors form, like red sunsets. I should explain step-by-step so even younger users can follow. Need to use simple terms, maybe analogies like comparing sunlight to a box of crayons. Also, mention other colors because that connects to their question about sunsets.\n\nWait, the user might not be aware that the sky appears blue during the day and not all colors are scattered equally. Should clarify that blue light scatters more due to its wavelength. But avoid jargon. Maybe talk about wave sizes being compared to air molecules, like a pebble in water versus a dust bunny.\n\nThey might not know about Rayleigh scattering's name, so brief mention is okay. Emphasize the importance of all colors being present in sunlight, then the filtering process. Also, address why sunsets are red—since that's related and might be an underlying question.\n\nI should structure the answer to first explain the general scattering, then focus on blue, then apply to day-time sky. Finally, the sunset effect as an extension. Keep it concise but thorough. Make sure to check if the explanation flows naturally without assuming prior knowledge of physics. Use everyday ex ...
